# %% [markdown]
# ## Roll No: 31440
# ## DSBDAL Assignment-10

# %% [markdown]
# ## Importing libraries

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df=pd.read_csv("Iris.csv")
df
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# ...

# %%
df.isnull().sum()
# Out:
# Id               0
# SepalLengthCm    0
# SepalWidthCm     0
# PetalLengthCm    0
# PetalWidthCm     0
# Species          0
# dtype: int64

# %%
df.dtypes
# Out:
# Id                 int64
# SepalLengthCm    float64
# SepalWidthCm     float64
# PetalLengthCm    float64
# PetalWidthCm     float64
# Species           object
# dtype: object

# %% [markdown]
# Features and there types
# 1)SepalLengthCm- Numeric
# 2)SepalWidthCm- Numeric
# 3)PetalLengthCm- Numeric
# 4)PetalWidthCm- Numeric
# 5)Species- Nominal

# %% [markdown]
# ### Histogram

# %%
plt.figure(figsize=(10,8))
sns.histplot(x=df["SepalLengthCm"],hue=df["Species"])
# Out:
# <AxesSubplot:xlabel='SepalLengthCm', ylabel='Count'>

# %%
plt.figure(figsize=(10,8))
sns.histplot(x=df["SepalWidthCm"],hue=df["Species"])
# Out:
# <AxesSubplot:xlabel='SepalWidthCm', ylabel='Count'>

# %%
plt.figure(figsize=(10,8))
sns.histplot(x=df["PetalLengthCm"],hue=df["Species"])
# Out:
# <AxesSubplot:xlabel='PetalLengthCm', ylabel='Count'>

# %%
plt.figure(figsize=(10,8))
sns.histplot(x=df["PetalWidthCm"],hue=df["Species"])
# Out:
# <AxesSubplot:xlabel='PetalWidthCm', ylabel='Count'>

# %%
plt.figure(figsize=(10,8))
sns.histplot(x=df["Species"],hue=df["Species"])
# Out:
# <AxesSubplot:xlabel='Species', ylabel='Count'>

# %%
sns.boxplot(x=df["Species"],y=df["SepalLengthCm"])
# Out:
# <AxesSubplot:xlabel='Species', ylabel='SepalLengthCm'>

# %%
sns.boxplot(x=df["Species"],y=df["SepalWidthCm"])
# Out:
# <AxesSubplot:xlabel='Species', ylabel='SepalWidthCm'>

# %%
sns.boxplot(x=df["Species"],y=df["PetalLengthCm"])
# Out:
# <AxesSubplot:xlabel='Species', ylabel='PetalLengthCm'>

# %%
sns.boxplot(x=df["Species"],y=df["PetalWidthCm"])
# Out:
# <AxesSubplot:xlabel='Species', ylabel='PetalWidthCm'>

# %%
df.plot(kind="box",subplots=True,layout=(4,4),fontsize=18,figsize=(22,22))
# Out:
# Id                  AxesSubplot(0.125,0.71587;0.168478x0.16413)
# SepalLengthCm    AxesSubplot(0.327174,0.71587;0.168478x0.16413)
# SepalWidthCm     AxesSubplot(0.529348,0.71587;0.168478x0.16413)
# PetalLengthCm    AxesSubplot(0.731522,0.71587;0.168478x0.16413)
# PetalWidthCm       AxesSubplot(0.125,0.518913;0.168478x0.16413)
# dtype: object
